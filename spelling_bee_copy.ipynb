# %% [markdown]
# ## Spelling Bee - Programa para brincar com as palavras
#
# A ideia do sistema é pegar todas as 250 palavras do Spelling Bee do Senac e fazer filtros:
#
# - filtrar apenas palavras maiores que X letras
# - filtrar apenas palavras com X quantidade de letras
# - filtrar palavras com letras específicas (por ex: h, y, que podem confundir)
# - filtrar palavras com letras duplas

# %% [markdown]
# ### Transformando as palavras em lista

# %%
# Coloquei todas as palavras numa mesma string. Elas estão separadas por enter (\n).
todas_as_palavras = '''Abhorrent
Absence
Absorption
Accommodating
Accomplice
Acreage
Acrimonious
Actuarial
Adjournment
Adjudicate
Adjustment
Affiliation
Agastache
Aggregate
Alacrity
Algerian
Algorithm
Allergen
Alleviate
Allure
Altruistic
Amnesty
Anachronism
Anchoring
Anglers
Anodyne
Apartheid
Apocalyptic
Apprehend
Armageddon
Arthritis
Assumption
Asthma
Aversion
Avoidance
Azalea
Baccalaureate
Backgammon
Backstabbing
Balderdash
Balustrade
Banishment
Bequeath
Berated
Bereavement
Bewilderment
Bingeing
Blasphemous
Boisterous
Bondholder
Braggart
Breadth
Brinkmanship
Buddhist
Bureaucracy
Burglarize
Bustling
Camaraderie
Camouflage
Campaign
Capacious
Capricious
Cataclysm
Catastrophic
Cautioned
Chameleon
Chastisement
Chauvinism
Chicory
Circuitous
Circumstantial
Circumvent
Clairvoyant
Clumsy
Collard
Committee
Compassionate
Conceivably
Concise
Consciousness
Consumption
Contempt
Conversely
Corroborate
Craveable
Daffodil
Dalliance
Dalmatian
Dampened
Dastardly
Daunting
Deadlock
Decadence
Deceased
Decipher
Decluttering
Deflationary
Delphinium
Demographic
Demoralize
Dereliction
Desalination
Desensitize
Deterrence
Dichotomy
Diligently
Diminished
Disproportionate
Distillation
Downstream
Eloquently
Embodied
Emboldened
Enrollment
Entrepreneur
Equitable
Ethereal
Ethnography
Eucalyptus
Evacuee
Excerpt
Exoskeleton
Fallacy
Fatigued
Fattening
Fieldwork
Fluctuation
Forfeiting
Fragile
Frittered
Ghostly
Gingivitis
Gooseberry
Gratitude
Guaranteed
Hazelnut
Heartwarming
Heckled
Hideous
Hindered
Hodgepodge
Homeowner
Hostile
Hyacinth
Idiosyncrasy
Immobilize
Inaugural
Inducement
Inning
Inquiry
Interviewee
Invariably
Ironclad
Jaundice
Kohlrabi
Laceration
Lawsuit
Leisurely
Liability
Licensing
Looting
Luminous
Malignancy
Mammoth
Mangosteen
Matriarchal
Meerkat
Meteorologist
Moneyed
Mulling
Newsworthy
Niftiest
Nightingale
Nimble
Nonaccrual
Nonexistent
Oblivious
Oddity
Osteoporosis
Outlining
Overarching
Passivizing
Pathetically
Patroller
Patronizing
Peaceable
Peculiar
Perception
Periphery
Perpetrator
Philodendron
Phylum
Pomegranate
Posthumous
Procedural
Readership
Reassurance
Reinvigorate
Reprieve
Rescinded
Resourcefulness
Restitution
Rhetorical
Rhinoceros
Rookie
Roulette
Rustling
Scorching
Seasoned
Shallots
Shepherd
Sightings
Skepticism
Slaughterhouse
Sleuthing
Solely
Soothing
Southeast
Stalemate
Stampede
Subsiding
Succeeded
Successor
Succumb
Suppress
Synthesize
Systematicity
Tennessee
Thoroughness
Thriving
Toppled
Tournament
Transcend
Transdisciplinary
Trespass
Unacceptable
Unbiased
Unbowed
Undergraduate
Unforeseen
Unobtrusive
Unprecedented
Unpredictable
Unsettle
Viewership
Voracious
Weakened
Whether
Whirring
Whisperer'''

# Criei uma variável de palavras separadas que pega a string com todas as palavras e separa em substrings sempre que encontr um \n
palavras_separadas = todas_as_palavras.split('\n')

# No print, as palavras aparecem como uma lista já separadas com as devidas aspas
print(palavras_separadas)

# %% [markdown]
# ### Criando a lista de todas as palavras

# %%
# Criei a lista de palavras com todas as palavras já separadas em strings

lista_de_palavras = ['Abhorrent', 'Absence', 'Absorption', 'Accommodating', 'Accomplice', 'Acreage', 'Acrimonious', 'Actuarial', 'Adjournment', 'Adjudicate', 'Adjustment', 'Affiliation', 'Agastache', 'Aggregate', 'Alacrity', 'Algerian', 'Algorithm', 'Allergen', 'Alleviate', 'Allure', 'Altruistic', 'Amnesty', 'Anachronism', 'Anchoring', 'Anglers', 'Anodyne', 'Apartheid', 'Apocalyptic', 'Apprehend', 'Armageddon', 'Arthritis', 'Assumption', 'Asthma', 'Aversion', 'Avoidance', 'Azalea', 'Baccalaureate', 'Backgammon', 'Backstabbing', 'Balderdash', 'Balustrade', 'Banishment', 'Bequeath', 'Berated', 'Bereavement', 'Bewilderment', 'Bingeing', 'Blasphemous', 'Boisterous', 'Bondholder', 'Braggart', 'Breadth', 'Brinkmanship', 'Buddhist', 'Bureaucracy', 'Burglarize', 'Bustling', 'Camaraderie', 'Camouflage', 'Campaign', 'Capacious', 'Capricious', 'Cataclysm', 'Catastrophic', 'Cautioned', 'Chameleon', 'Chastisement', 'Chauvinism', 'Chicory', 'Circuitous', 'Circumstantial', 'Circumvent', 'Clairvoyant', 'Clumsy', 'Collard', 'Committee', 'Compassionate', 'Conceivably', 'Concise', 'Consciousness', 'Consumption', 'Contempt', 'Conversely', 'Corroborate', 'Craveable', 'Daffodil', 'Dalliance', 'Dalmatian', 'Dampened', 'Dastardly', 'Daunting', 'Deadlock', 'Decadence', 'Deceased', 'Decipher', 'Decluttering', 'Deflationary', 'Delphinium', 'Demographic', 'Demoralize', 'Dereliction', 'Desalination', 'Desensitize', 'Deterrence', 'Dichotomy', 'Diligently', 'Diminished', 'Disproportionate', 'Distillation', 'Downstream', 'Eloquently', 'Embodied', 'Emboldened', 'Enrollment', 'Entrepreneur', 'Equitable', 'Ethereal', 'Ethnography', 'Eucalyptus', 'Evacuee', 'Excerpt', 'Exoskeleton', 'Fallacy', 'Fatigued', 'Fattening', 'Fieldwork', 'Fluctuation', 'Forfeiting', 'Fragile', 'Frittered', 'Ghostly', 'Gingivitis', 'Gooseberry', 'Gratitude', 'Guaranteed', 'Hazelnut', 'Heartwarming', 'Heckled', 'Hideous', 'Hindered', 'Hodgepodge', 'Homeowner', 'Hostile', 'Hyacinth', 'Idiosyncrasy', 'Immobilize', 'Inaugural', 'Inducement', 'Inning', 'Inquiry', 'Interviewee', 'Invariably', 'Ironclad', 'Jaundice', 'Kohlrabi', 'Laceration', 'Lawsuit', 'Leisurely', 'Liability', 'Licensing', 'Looting', 'Luminous', 'Malignancy', 'Mammoth', 'Mangosteen', 'Matriarchal', 'Meerkat', 'Meteorologist', 'Moneyed', 'Mulling', 'Newsworthy', 'Niftiest', 'Nightingale', 'Nimble', 'Nonaccrual', 'Nonexistent', 'Oblivious', 'Oddity', 'Osteoporosis', 'Outlining', 'Overarching', 'Passivizing', 'Pathetically', 'Patroller', 'Patronizing', 'Peaceable', 'Peculiar', 'Perception', 'Periphery', 'Perpetrator', 'Philodendron', 'Phylum', 'Pomegranate', 'Posthumous', 'Procedural', 'Readership', 'Reassurance', 'Reinvigorate', 'Reprieve', 'Rescinded', 'Resourcefulness', 'Restitution', 'Rhetorical', 'Rhinoceros', 'Rookie', 'Roulette', 'Rustling', 'Scorching', 'Seasoned', 'Shallots', 'Shepherd', 'Sightings', 'Skepticism', 'Slaughterhouse', 'Sleuthing', 'Solely', 'Soothing', 'Southeast', 'Stalemate', 'Stampede', 'Subsiding', 'Succeeded', 'Successor', 'Succumb', 'Suppress', 'Synthesize', 'Systematicity', 'Tennessee', 'Thoroughness', 'Thriving', 'Toppled', 'Tournament', 'Transcend', 'Transdisciplinary', 'Trespass', 'Unacceptable', 'Unbiased', 'Unbowed', 'Undergraduate', 'Unforeseen', 'Unobtrusive', 'Unprecedented', 'Unpredictable', 'Unsettle', 'Viewership', 'Voracious', 'Weakened', 'Whether', 'Whirring', 'Whisperer']

# %% [markdown]
# ### Filtro de palavras com X quantidade de letras

# %%
# Criei uma variável que recebe o número de letras por input
# Em seguida, o programa pesquisa cada palavra na lista palavras_separadas e confere se elas tem aquela quantidade de letras

numero_de_letras = int(input("Digite a quantidade de letras da palavra: "))

for palavra in lista_de_palavras:
    if len(palavra) == numero_de_letras:
        print(palavra)
# Out:
# Allure
# Asthma
# Azalea
# Clumsy
# Inning
# Nimble
# Oddity
# Phylum
# Rookie
# Solely

# %% [markdown]
# ### Filtro de palavras com mínimo de X letras

# %%
numero_de_letras = int(input("Mínimo de letras: "))

for palavra in lista_de_palavras:
    if len(palavra) >= numero_de_letras:
        print(palavra)
# Out:
# Accommodating
# Baccalaureate
# Backstabbing
# Bewilderment
# Brinkmanship
# Catastrophic
# Chastisement
# Circumstantial
# Compassionate
# Consciousness
# Decluttering
# Deflationary
# Desalination
# Disproportionate
# Distillation
# Entrepreneur
# Heartwarming
# Idiosyncrasy
# Meteorologist
# Osteoporosis
# Pathetically
# Philodendron
# Reinvigorate
# Resourcefulness
# Slaughterhouse
# Systematicity
# Thoroughness
# Transdisciplinary
# Unacceptable
# Undergraduate
# Unprecedented
# Unpredictable

# %% [markdown]
# ### Filtrando palavras com uma letra específica

# %%
# Criei uma variável letra_escolhida que recebe a letra (ou conjunto de letras) da palavra
# O programa passa por todas as palavras e imprime as que tem a letra

letra_escolhida = input('Digite a letra na palavra: ')

for palavra in palavras_separadas:
    if letra_escolhida in palavra:
        print(palavra)
# Out:
# Adjournment
# Adjudicate
# Adjustment

# %% [markdown]
# ### Outras coisas para testar:
#
# - Sortear palavra
# - sortear palavra pelo número
# - remover palavra acertada
#
# - menu para jogar ou consultar

# %%
### sortear palavra pelo numero

numero = int(input('Digite um número para ver a palavra: '))

print(lista_de_palavras[numero])


## Remover 

lista_de_palavras.remove('Acreage')

print(lista_de_palavras)
